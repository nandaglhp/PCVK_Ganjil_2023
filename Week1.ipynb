# %% [markdown]
# <a href="https://colab.research.google.com/github/nandaglhp/PCVK_Ganjil_2023/blob/main/Week1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import cv2 as cv
from google.colab.patches import cv2_imshow # for image display
from skimage import io
from skimage import transform
from PIL import Image
import matplotlib.pylab as plt

# %%
# Membuat list untuk menyimpan url dari beberapa image
urls = ["https://iiif.lib.ncsu.edu/iiif/0052574/full/800,/0/default.jpg",
        "https://iiif.lib.ncsu.edu/iiif/0016007/full/800,/0/default.jpg",
        "https://placekitten.com/800/571"]
# baca dan tampilkan image
# loop pada tiap url image, beberapa image dapat disimpan pada list
for url in urls:
  image = io.imread(url)                            # read image
  image = cv.resize(image, (0,0), fx=0.5, fy=0.5)   # resize image to half size
  image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)    # convert color to RGB
  final_frame = cv.hconcat((image, image_2))        # concatenate image
  cv2_imshow(final_frame)                           # show image
  print('\n')
# Out:
# <PIL.Image.Image image mode=RGB size=800x276>
# <PIL.Image.Image image mode=RGB size=800x286>
# <PIL.Image.Image image mode=RGB size=800x286>

# %% [markdown]
# Langkah (Step) 3
#
# melihat ukuran file image

# %%
tinggi = image_2.shape[0]
lebar = image_2.shape[1]
print("resolusi image: tinggi x lebar = ", tinggi, " x ", lebar)
cv2_imshow(image_2)
# Out:
# resolusi image: tinggi x lebar =  286  x  400
# <PIL.Image.Image image mode=RGB size=400x286>

# %% [markdown]
# Langkah (Step) 4
#
# mengakses pixel dengan memberi garis diagonal menyilang

# %%
image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)
image_3 = cv.cvtColor(image, cv.COLOR_BGR2RGB)

# membuat garis horizontal di tengah image
for y in range (lebar):
  image_3[int((tinggi)/2),y] = [255,255,255]

final_frame = cv.hconcat((image_2, image_3))
cv2_imshow(final_frame)
# Out:
# <PIL.Image.Image image mode=RGB size=800x286>

# %% [markdown]
# # **Jawaban :**
#
# 1. aksesibilitas (platform berbasis cloud yang memungkinkan menjalankan kode Python di lingkungan yang sudah siap digunakan tanpa perlu mengatur atau menginstal perangkat lunak secara lokal di komputer), paket library siap pakai, bisa kolaborasi, mudah untuk menyimpan hasil pekerjaan dan gratis.
#
# 2. NumPy = array dan fungsi matematika
#
#   Pandas = analisis data dan manipulasi data terstruktur
#
#   skimage = melakukan berbagai tugas pemrosesan gambar, analisis, dan manipulasi.
#
#   OpenCV = memproses dan menganalisis citra
#
#   PIL = manipulasi gambar dalam berbagai format, membuka, mengedit, dan menyimpan gambar dengan mudah, serta melakukan berbagai operasi pemrosesan gambar.
#
#   matplotlib = membuat grafik, plot, diagram, dan visualisasi lainnya dari data numerik.
#
#   google.colab.patches.cv2_imshow = menampilkan gambar
#
#   from skimage import io = 'io' digunakan untuk operasi input/output pada gambar. jugd digunakan untuk membaca dan menyimpan gambar dalam berbagai format.
#
#   from skimage import transform = 'transform' berbagai fungsi yang berkaitan dengan transformasi geometris pada gambar. dapat digunakan untuk melakukan operasi seperti pergeseran, rotasi, perubahan skala, dan lainnya pada gambar.
#
#   from PIL import Image = membuka, menyimpan, dan mengedit gambar dalam berbagai format, serta mengelola elemen gambar seperti piksel dan ukuran gambar.
#
#   import matplotlib.pylab as plt = membuat plot, diagram, dan visualisasi lainnya dari data numerik.
#
# 3. kegunaan kode program tersebut untuk menciptakan gambar baru dengan ukuran yang lebih kecil. faktor skala '0.5' berati ukuran gambar yang dihasilkan akan menjadi setengah dari ukuran aslinya.
#
# 4. [255, 255, 255] adalah nilai yang mewakili warna dalam format RGB (Red, Green, Blue). masing-masing dalam rentang 0 hingga 255. Kode [255, 255, 255] menggambarkan warna putih. Dalam format RGB, ketiga komponen warna diatur ke nilai maksimum (255), untuk menghasilkan warna putih yang penuh. kombinasi nilai tinggi pada ketiga komponen warna ini menghasilkan warna yang tidak memiliki dominasi warna apapun, sehingga menghasilkan warna putih yang netral. warna putih digunakan sebagai warna dari garis horizontal. Jika kode yang digunakan bukan [255, 255, 255] namun menggunakan kombinasi nilai lain, maka akan menghasilkan warna yang berbeda. Yang mana akan mempengaruhi warna garis yang dibuat di tengah gambar.
#
# 5. Semakin banyak pixel yang ada dalam gambar, semakin tinggi resolusi gambar tersebut. Karena pixel adalah dasar yang membentuk resolusi. Jadi, semakin tinggi resolusi gambar, maka semakin banyak pula pixel yang digunakan untuk membentuk gambar tersebut. Ini memberikan gambar yang lebih rinci dan berkualitas baik. Sebaliknya, semakin rendah resolusi gambar, semakin sedikit pixel yang digunakan, yang dapat mengakibatkan gambar dengan kurangnya detail dan kualitas rendah.

# %% [markdown]
# # **E. Tugas**
#
# Buat garis vertikal pada image keluaran

# %%
image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)
image_3 = cv.cvtColor(image, cv.COLOR_BGR2RGB)

# membuat garis vertikal di tengah image
ver = lebar // 2  # Tentukan kolom di tengah gambar

for y in range(tinggi):
    image_3[y, ver] = [255, 255, 255]

final_frame = cv.hconcat((image_2, image_3))
cv2_imshow(final_frame)
# Out:
# <PIL.Image.Image image mode=RGB size=800x286>

# %% [markdown]
# 2. Buat garis menyilang diagonal pada image keluaran!

# %%
image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)
image_3 = cv.cvtColor(image, cv.COLOR_BGR2RGB)

# garis diagonal di tangah gambar

for x in range(min(tinggi,lebar)):
  y = x * lebar // tinggi
  image_3[x,int(y)] = [255,255,255]
  image_3[-x,int(y)] = [255,255,255]

final_frame = cv.hconcat((image_2, image_3))
cv2_imshow(final_frame)
# Out:
# <PIL.Image.Image image mode=RGB size=800x286>

# %% [markdown]
# 3. Buat garis horisontal berwarna putih dibagian tengah gambar dengan panjang
# tertentu

# %%
panjang_garis = 100  # Panjang garis

image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)
image_3 = cv.cvtColor(image, cv.COLOR_BGR2RGB)

# Tentukan baris tengah
baris_tengah = tinggi // 2

# Loop untuk mengganti warna piksel pada garis horizontal
for x in range(lebar):
    if x >= (lebar // 2) - (panjang_garis // 2) and x < (lebar // 2) + (panjang_garis // 2):
        image_3[baris_tengah, x] = [255, 255, 255]

final_frame = cv.hconcat((image_2, image_3))
cv2_imshow(final_frame)
# Out:
# <PIL.Image.Image image mode=RGB size=800x286>

# %% [markdown]
# 4. Buat kotak menggunakan kumpulan pixel warna putih di sembarang tempat dalam
# gambar

# %%
image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)
image_3 = cv.cvtColor(image, cv.COLOR_BGR2RGB)

# length
p = int((tinggi)/3)

# width
l = int((lebar)/3)

for y in range(p,l):
  for x in range(p,l):
    image_3[x,y] = [255,255,255]

final_frame = cv.hconcat((image_2, image_3))
cv2_imshow(final_frame)
# Out:
# <PIL.Image.Image image mode=RGB size=800x286>

# %% [markdown]
# 1. Akses file image lokal (KTP/SIM) dan tampilkan menggunakan OpenCV dan Matplotlib

# %%
import numpy as np
import pandas as pd
import cv2 as cv
from google.colab.patches import cv2_imshow # for image display
from skimage import io
from skimage import transform
from PIL import Image
import matplotlib.pylab as plt

image_ktp = cv.imread('KTP.jpeg')
cv2_imshow(image_ktp)
# Out:
# <PIL.Image.Image image mode=RGB size=800x488>

# %% [markdown]
# 2. Ketika menggunakan OpenCV untuk membaca gambar dari file, gambar tersebut dalam format warna BGR. Jika ingin menampilkan gambar menggunakan Matplotlib perlu mengonversi format warna dari BGR ke RGB agar tampilan warnanya sesuai dengan harapan.

# %% [markdown]
# Tutup bagian agama dan status kawin
